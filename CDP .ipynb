# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as sns

df=pd.read_csv(r"C:\Users\Palash Karmakar\Desktop\Python and AI\cardio_train_modified.csv")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# no null values there moving on to loc columns

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# Cholesterol

# %%
plt.scatter(df.index,df.cholesterol)

# %%
plt.scatter(df.age,df.cholesterol)

# %%
plt.scatter(df.gender,df.cholesterol)

# %%
plt.scatter(df.height,df.cholesterol)

# %%
plt.scatter(df.weight,df.cholesterol)

# %%
x1=df.iloc[:,1:7]
x1
# Out:
#          age  gender  height  weight  ap_hi  ap_lo
# 0      18393       2     168    62.0    110     80
# 1      20228       1     156    85.0    140     90
# 2      18857       1     165    64.0    130     70
# 3      17623       2     169    82.0    150    100
# 4      17474       1     156    56.0    100     60
# ...      ...     ...     ...     ...    ...    ...
# 69995  19240       2     168    76.0    120     80
# 69996  22601       1     158   126.0    140     90
# 69997  19066       2     183   105.0    180     90
# 69998  22431       1     163    72.0    135     80
# 69999  20540       1     170    72.0    120     80
#
# [70000 rows x 6 columns]

# %%
y1=df.iloc[:,7:8]
y1
# Out:
#        cholesterol
# 0                1
# 1                3
# 2                3
# 3                1
# 4                1
# ...            ...
# 69995            1
# 69996            2
# 69997            3
# 69998            1
# 69999            2
#
# [70000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x1train,x1test,y1train,y1test=train_test_split(x1,y1,train_size=0.8)

# %%
x1train
# Out:
#          age  gender  height  weight  ap_hi  ap_lo
# 26736  19859       1     159    49.0    110     90
# 67360  23144       2     176    65.0    120     80
# 49602  14430       1     157    55.0    120     80
# 22864  19033       1     162    59.0    110     70
# 68684  14702       1     160   100.0    120     80
# ...      ...     ...     ...     ...    ...    ...
# 63152  21083       1     165    87.0    110     80
# 23124  17578       2     175    80.0    120     70
# 25809  20686       1     158    73.0    140     80
# 46767  18777       1     157    63.0    120     80
# 58148  20478       2     172    80.0    120     80
#
# [56000 rows x 6 columns]

# %%
x1test
# Out:
#          age  gender  height  weight  ap_hi  ap_lo
# 26593  22614       2     160    86.0    120     70
# 64996  19791       1     168    71.0    120     90
# 43260  23500       2     168    76.0    140     90
# 5867   21154       1     158    53.0    120     80
# 62132  19220       1     168    68.0    150     80
# ...      ...     ...     ...     ...    ...    ...
# 35188  15183       2     181   100.0    150     90
# 52786  15467       1     171    69.0    110     70
# 51909  23228       1     142   129.0    140     90
# 33441  20586       1     153    68.0    100     70
# 30968  14778       1     162    53.0    150    100
#
# [14000 rows x 6 columns]

# %%
y1train
# Out:
#        cholesterol
# 26736            1
# 67360            1
# 49602            1
# 22864            1
# 68684            1
# ...            ...
# 63152            1
# 23124            1
# 25809            1
# 46767            1
# 58148            2
#
# [56000 rows x 1 columns]

# %%
y1test
# Out:
#        cholesterol
# 26593            3
# 64996            1
# 43260            2
# 5867             1
# 62132            1
# ...            ...
# 35188            1
# 52786            1
# 51909            1
# 33441            1
# 30968            2
#
# [14000 rows x 1 columns]

# %%
from sklearn.svm import SVC
chol_model=SVC()

# %%
chol_model
# Out:
# SVC()

# %%
chol_model.fit(x1train,y1train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
chol_model.predict(x1test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
chol_model.score(x1test,y1test)
# Out:
# 0.7472142857142857

# %% [markdown]
# Glucose

# %%
plt.scatter(df.index,df.gluc)

# %%
plt.scatter(df.age,df.gluc)

# %%
plt.scatter(df.age,df.gluc)

# %%
plt.scatter(df.gender,df.gluc)

# %%
plt.scatter(df.height,df.gluc)

# %%
plt.scatter(df.weight,df.gluc)

# %%
x2=df.iloc[:,1:7]

# %%
y2=df.iloc[:,8:9]

# %%
x2train,x2test,y2train,y2test=train_test_split(x2,y2,train_size=0.8)

# %%
gluc_model=SVC()

# %%
gluc_model.fit(x2train,y2train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
gluc_model.predict(x2test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
gluc_model.score(x2test,y2test)
# Out:
# 0.8514285714285714

# %% [markdown]
# Smoke

# %%
plt.scatter(df.index,df.smoke)

# %%
plt.scatter(df.age,df.smoke)

# %%
plt.scatter(df.gender,df.smoke)

# %%
plt.scatter(df.height,df.smoke)

# %%
plt.scatter(df.weight,df.smoke)

# %%
x3=df.iloc[:,1:7]
y3=df.iloc[:,9:10]

# %%
x3train,x3test,y3train,y3test=train_test_split(x3,y3,train_size=0.8)

# %%
smk_model=SVC()

# %%
smk_model.fit(x3train,y3train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
smk_model.predict(x3test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
smk_model.score(x3test,y3test)
# Out:
# 0.9123571428571429

# %% [markdown]
# Alcohol

# %%
plt.scatter(df.index,df.alco)

# %%
plt.scatter(df.age,df.alco)

# %%
plt.scatter(df.gender,df.alco)

# %%
plt.scatter(df.height,df.alco)

# %%
plt.scatter(df.weight,df.alco)

# %%
x4=df.iloc[:,1:7]
y4=df.iloc[:,10:11]

# %%
x4train,x4test,y4train,y4test=train_test_split(x4,y4,train_size=0.8)

# %%
alco_model=SVC()

# %%
alco_model.fit(x4train,y4train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
alco_model.predict(x4test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
alco_model.score(x4test,y4test)
# Out:
# 0.9433571428571429

# %% [markdown]
# Active

# %%
plt.scatter(df.index,df.active)

# %%
plt.scatter(df.age,df.active)

# %%
plt.scatter(df.gender,df.active)

# %%
plt.scatter(df.weight,df.active)

# %%
x5=df.iloc[:,1:7]
y5=df.iloc[:,11:12]

# %%
x5train,x5test,y5train,y5test=train_test_split(x5,y5,train_size=0.8)

# %%
act_model=SVC()

# %%
act_model.fit(x5train,y5train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
act_model.predict(x5test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
act_model.score(x5test,y5test)
# Out:
# 0.8061428571428572

# %% [markdown]
# Cardio

# %%
plt.scatter(df.index,df.cardio)

# %%
plt.scatter(df.age,df.cardio)

# %%
plt.scatter(df.gender,df.cardio)

# %%
plt.scatter(df.weight,df.cardio)

# %%
x6=df.iloc[:,1:7]
y6=df.iloc[:,12:13]
y6
# Out:
#        cardio
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 69995       0
# 69996       1
# 69997       1
# 69998       1
# 69999       0
#
# [70000 rows x 1 columns]

# %%
x6train,x6test,y6train,y6test=train_test_split(x6,y6,train_size=0.8)

# %%
crd_model=SVC()

# %%
crd_model.fit(x6train,y6train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
crd_model.predict(x6test)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
crd_model.score(x6test,y6test)
# Out:
# 0.5992857142857143

# %% [markdown]
# # KNN

# %% [markdown]
# Cholestrol

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_chlstrl=KNeighborsClassifier()

# %%
knn_chlstrl.fit(x1train,y1train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_chlstrl.predict(x1test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
knn_chlstrl.score(x1test,y1test)
# Out:
# 0.7232857142857143

# %% [markdown]
# Glucose

# %%
knn_gluc=KNeighborsClassifier()

# %%
knn_gluc.fit(x2train,y2train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_gluc.predict(x2test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
knn_gluc.score(x2test,y2test)
# Out:
# 0.8435714285714285

# %% [markdown]
# Smoke

# %%
knn_smk=KNeighborsClassifier()

# %%
knn_smk.fit(x3train,y3train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_smk.predict(x3test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
knn_smk.score(x3test,y3test)
# Out:
# 0.9066428571428572

# %% [markdown]
# Alcohol

# %%
knn_alco=KNeighborsClassifier()

# %%
knn_alco.fit(x4train,y4train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_alco.predict(x4test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
knn_alco.score(x4test,y4test)
# Out:
# 0.9422142857142857

# %% [markdown]
# Active

# %%
knn_active=KNeighborsClassifier()

# %%
knn_active.fit(x5train,y5train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_active.predict(x5test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
knn_active.score(x5test,y5test)
# Out:
# 0.7744285714285715

# %% [markdown]
# Cardio

# %%
knn_cardio=KNeighborsClassifier()

# %%
knn_cardio.fit(x6train,y6train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_cardio.predict(x6test)
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
knn_cardio.score(x6test,y6test)
# Out:
# 0.6787142857142857

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Cholesterol

# %%
rf_chlstrl=RandomForestClassifier()

# %%
rf_chlstrl.fit(x1train,y1train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\2192313461.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_chlstrl.fit(x1train,y1train)
# RandomForestClassifier()

# %%
rf_chlstrl.predict(x1test)
# Out:
# array([1, 1, 1, ..., 3, 1, 1], dtype=int64)

# %%
rf_chlstrl.score(x1test,y1test)
# Out:
# 0.7224285714285714

# %% [markdown]
# Glucose

# %%
rf_gluc=RandomForestClassifier()

# %%
rf_gluc.fit(x2train,y2train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\1417890143.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_gluc.fit(x2train,y2train)
# RandomForestClassifier()

# %%
rf_gluc.predict(x2test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
rf_gluc.score(x2test,y2test)
# Out:
# 0.8419285714285715

# %% [markdown]
# Smoke

# %%
rf_smk=RandomForestClassifier()

# %%
rf_smk.fit(x3train,y3train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\2869640221.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_smk.fit(x3train,y3train)
# RandomForestClassifier()

# %%
rf_smk.predict(x3test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rf_smk.score(x3test,y3test)
# Out:
# 0.9019285714285714

# %% [markdown]
# Alcohol

# %%
rf_alco=RandomForestClassifier()

# %%
rf_alco.fit(x4train,y4train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\978313621.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_alco.fit(x4train,y4train)
# RandomForestClassifier()

# %%
rf_alco.predict(x4test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rf_alco.score(x4test,y4test)
# Out:
# 0.9412857142857143

# %% [markdown]
# Active

# %%
rf_act=RandomForestClassifier()

# %%
rf_act.fit(x5train,y5train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\4276011139.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_act.fit(x5train,y5train)
# RandomForestClassifier()

# %%
rf_act.predict(x5test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
rf_act.score(x5test,y5test)
# Out:
# 0.7801428571428571

# %% [markdown]
# Cardio

# %%
rf_crd=RandomForestClassifier()

# %%
rf_crd.fit(x6train,y6train)
# Out:
# C:\Users\Palash Karmakar\AppData\Local\Temp\ipykernel_8364\1471588204.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_crd.fit(x6train,y6train)
# RandomForestClassifier()

# %%
rf_crd.predict(x6test)
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
rf_crd.score(x6test,y6test)
# Out:
# 0.6959285714285715

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# Cholestrol

# %%
dt_chlstrl=DecisionTreeClassifier()

# %%
dt_chlstrl.fit(x1train,y1train)
# Out:
# DecisionTreeClassifier()

# %%
dt_chlstrl.predict(x1test)
# Out:
# array([1, 1, 1, ..., 2, 1, 1], dtype=int64)

# %%
dt_chlstrl.score(x1test,y1test)
# Out:
# 0.607

# %%
tree.plot_tree(dt_chlstrl)
# Out:
# [Text(0.5046665202521794, 0.9888888888888889, 'x[4] <= 128.5\ngini = 0.408\nsamples = 56000\nvalue = [41924, 7638, 6438]'),
#  Text(0.27831437131227366, 0.9666666666666667, 'x[0] <= 19988.5\ngini = 0.296\nsamples = 32961\nvalue = [27350, 3421, 2190]'),
#  Text(0.16723990422189536, 0.9444444444444444, 'x[3] <= 86.5\ngini = 0.256\nsamples = 20373\nvalue = [17428, 2079, 866]'),
#  Text(0.09229172514820715, 0.9222222222222223, 'x[0] <= 17297.5\ngini = 0.242\nsamples = 18265\nvalue = [15789, 1755, 721]'),
#  Text(0.03612587799196489, 0.9, 'x[4] <= 118.0\ngini = 0.197\nsamples = 7544\nvalue = [6729, 636, 179]'),
#  Text(0.026582393434202056, 0.8777777777777778, 'x[2] <= 180.5\ngini = 0.218\nsamples = 3250\nvalue = [2853, 337, 60]'),
#  Text(0.02129201253268795, 0.8555555555555555, 'x[4] <= -49.5\ngini = 0.216\nsamples = 3219\nvalue = [2831, 328, 60]'),
#  Text(0.018326606570318777, 0.8333333333333334, 'x[5] <= 75.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
# ...

# %% [markdown]
# Glucose

# %%
dt_gluc=DecisionTreeClassifier()

# %%
dt_gluc.fit(x2train,y2train)
# Out:
# DecisionTreeClassifier()

# %%
dt_gluc.predict(x2test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
dt_gluc.score(x2test,y2test)
# Out:
# 0.7186428571428571

# %%
tree.plot_tree(dt_gluc)
# Out:
# [Text(0.5544727380348968, 0.9883720930232558, 'x[4] <= 125.5\ngini = 0.267\nsamples = 56000\nvalue = [47559, 4167, 4274]'),
#  Text(0.30045512305024297, 0.9651162790697675, 'x[3] <= 80.9\ngini = 0.212\nsamples = 32910\nvalue = [29084, 1891, 1935]'),
#  Text(0.1414940945105344, 0.9418604651162791, 'x[0] <= 18213.5\ngini = 0.192\nsamples = 26669\nvalue = [23885, 1327, 1457]'),
#  Text(0.07401029091170194, 0.9186046511627907, 'x[3] <= 75.5\ngini = 0.154\nsamples = 9544\nvalue = [8761, 479, 304]'),
#  Text(0.04190528455219163, 0.8953488372093024, 'x[3] <= 60.6\ngini = 0.147\nsamples = 8320\nvalue = [7669, 393, 258]'),
#  Text(0.019326665831118268, 0.872093023255814, 'x[5] <= 30.0\ngini = 0.124\nsamples = 2530\nvalue = [2365, 107, 58]'),
#  Text(0.01701734214117762, 0.8488372093023255, 'x[0] <= 16419.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.016922730837030088, 0.8255813953488372, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
# ...

# %% [markdown]
# Smoke

# %%
dt_smk=DecisionTreeClassifier()

# %%
dt_smk.fit(x3train,y3train)
# Out:
# DecisionTreeClassifier()

# %%
dt_smk.predict(x3test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
dt_smk.score(x3test,y3test)
# Out:
# 0.8580714285714286

# %%
tree.plot_tree(dt_smk)
# Out:
# [Text(0.43980241202639464, 0.9886363636363636, 'x[1] <= 1.5\ngini = 0.161\nsamples = 56000\nvalue = [51058, 4942]'),
#  Text(0.1596970022178971, 0.9659090909090909, 'x[3] <= 126.5\ngini = 0.034\nsamples = 36416\nvalue = [35780, 636]'),
#  Text(0.10169335579440193, 0.9431818181818182, 'x[0] <= 18099.5\ngini = 0.034\nsamples = 36261\nvalue = [35638, 623]'),
#  Text(0.04231204134974463, 0.9204545454545454, 'x[3] <= 79.5\ngini = 0.044\nsamples = 9395\nvalue = [9184, 211]'),
#  Text(0.023156462902197326, 0.8977272727272727, 'x[3] <= 52.5\ngini = 0.037\nsamples = 7174\nvalue = [7039, 135]'),
#  Text(0.005731292828332754, 0.875, 'x[0] <= 18066.0\ngini = 0.073\nsamples = 552\nvalue = [531, 21]'),
#  Text(0.004237831109158475, 0.8522727272727273, 'x[5] <= 47.5\ngini = 0.067\nsamples = 545\nvalue = [526, 19]'),
#  Text(0.0033072778418486585, 0.8295454545454546, 'x[0] <= 14897.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...

# %% [markdown]
# Alcohol

# %%
dt_alco=DecisionTreeClassifier()

# %%
dt_alco.fit(x4train,y4train)
# Out:
# DecisionTreeClassifier()

# %%
dt_alco.predict(x4test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
dt_alco.score(x4test,y4test)
# Out:
# 0.8912857142857142

# %%
tree.plot_tree(dt_alco)
# Out:
# [Text(0.5161676356106958, 0.9883720930232558, 'x[1] <= 1.5\ngini = 0.1\nsamples = 56000\nvalue = [53029, 2971]'),
#  Text(0.26126817118518375, 0.9651162790697675, 'x[3] <= 82.75\ngini = 0.049\nsamples = 36466\nvalue = [35551, 915]'),
#  Text(0.2003709426723125, 0.9418604651162791, 'x[2] <= 197.0\ngini = 0.042\nsamples = 28881\nvalue = [28255, 626]'),
#  Text(0.15870588332420338, 0.9186046511627907, 'x[2] <= 164.5\ngini = 0.042\nsamples = 28879\nvalue = [28254, 625]'),
#  Text(0.0761349518639273, 0.8953488372093024, 'x[3] <= 64.25\ngini = 0.047\nsamples = 19049\nvalue = [18587, 462]'),
#  Text(0.01179814683062961, 0.872093023255814, 'x[4] <= 1251.0\ngini = 0.038\nsamples = 8393\nvalue = [8231, 162]'),
#  Text(0.011545084418648884, 0.8488372093023255, 'x[0] <= 14340.0\ngini = 0.038\nsamples = 8392\nvalue = [8231, 161]'),
#  Text(0.0007591872359421776, 0.8255813953488372, 'x[0] <= 14336.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
# ...

# %% [markdown]
# Active

# %%
dt_act=DecisionTreeClassifier()

# %%
dt_act.fit(x5train,y5train)
# Out:
# DecisionTreeClassifier()

# %%
dt_act.predict(x5test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
dt_act.score(x5test,y5test)
# Out:
# 0.676

# %%
tree.plot_tree(dt_act)
# Out:
# [Text(0.5664045389875184, 0.9928571428571429, 'x[3] <= 83.8\ngini = 0.316\nsamples = 56000\nvalue = [11025, 44975]'),
#  Text(0.22112592643666995, 0.9785714285714285, 'x[4] <= 110.5\ngini = 0.311\nsamples = 43322\nvalue = [8337, 34985]'),
#  Text(0.08050538442739923, 0.9642857142857143, 'x[0] <= 22932.0\ngini = 0.29\nsamples = 8933\nvalue = [1572, 7361]'),
#  Text(0.019525108497714817, 0.95, 'x[2] <= 145.5\ngini = 0.285\nsamples = 8597\nvalue = [1482, 7115]'),
#  Text(0.0006578225047245952, 0.9357142857142857, 'x[5] <= 65.0\ngini = 0.442\nsamples = 79\nvalue = [26, 53]'),
#  Text(0.0003827330936579463, 0.9214285714285714, 'x[3] <= 61.0\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.00028704982024345974, 0.9071428571428571, 'x[0] <= 16080.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.00019136654682897316, 0.8928571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
# ...

# %% [markdown]
# Cardio

# %%
dt_crd=DecisionTreeClassifier()

# %%
dt_crd.fit(x6train,y6train)
# Out:
# DecisionTreeClassifier()

# %%
dt_crd.predict(x6test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
dt_crd.score(x6test,y6test)
# Out:
# 0.6202142857142857

# %%
tree.plot_tree(dt_crd)
# Out:
# [Text(0.5707580933454083, 0.9912280701754386, 'x[4] <= 129.5\ngini = 0.5\nsamples = 56000\nvalue = [28041, 27959]'),
#  Text(0.340906810965092, 0.9736842105263158, 'x[0] <= 19994.5\ngini = 0.435\nsamples = 33147\nvalue = [22572, 10575]'),
#  Text(0.14161679570510782, 0.956140350877193, 'x[0] <= 16303.5\ngini = 0.363\nsamples = 20501\nvalue = [15624, 4877]'),
#  Text(0.03756099805215567, 0.9385964912280702, 'x[4] <= 113.5\ngini = 0.261\nsamples = 6142\nvalue = [5196, 946]'),
#  Text(0.010432573328125876, 0.9210526315789473, 'x[3] <= 62.5\ngini = 0.198\nsamples = 2582\nvalue = [2295, 287]'),
#  Text(0.0010058706547405826, 0.9035087719298246, 'x[2] <= 192.5\ngini = 0.137\nsamples = 998\nvalue = [924, 74]'),
#  Text(0.0009202846474426411, 0.8859649122807017, 'x[5] <= 135.0\ngini = 0.136\nsamples = 997\nvalue = [924, 73]'),
#  Text(0.0008346986401446997, 0.868421052631579, 'x[0] <= 14296.5\ngini = 0.134\nsamples = 996\nvalue = [924, 72]'),
# ...

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Cholestrol

# %%
lr_chl=LogisticRegression()

# %%
lr_chl.fit(x1train,y1train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_chl.predict(x1test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
lr_chl.score(x1test,y1test)
# Out:
# 0.7461428571428571

# %% [markdown]
# Glucose

# %%
lr_gluc=LogisticRegression()

# %%
lr_gluc.fit(x2train,y2train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_gluc.predict(x2test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
lr_gluc.score(x2test,y2test)
# Out:
# 0.851

# %% [markdown]
# Smoke

# %%
lr_smk=LogisticRegression()

# %%
lr_smk.fit(x3train,y3train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_smk.predict(x3test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
lr_smk.score(x3test,y3test)
# Out:
# 0.9120714285714285

# %% [markdown]
# Alcohol

# %%
lr_alco=LogisticRegression()

# %%
lr_alco.fit(x4train,y4train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_alco.predict(x4test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
lr_alco.score(x4test,y4test)
# Out:
# 0.9433571428571429

# %% [markdown]
# Active

# %%
lr_act=LogisticRegression()

# %%
lr_act.fit(x5train,y5train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lr_act.predict(x5test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
lr_act.score(x5test,y5test)
# Out:
# 0.8061428571428572

# %% [markdown]
# Cardio

# %%
lr_crd=LogisticRegression()

# %%
lr_crd.fit(x6train,y6train)
# Out:
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Palash Karmakar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_crd.predict(x6test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
lr_crd.score(x6test,y6test)
# Out:
# 0.501
